# %% [markdown]
# # dff9: HW0 and HW1

# %% [markdown]
# ## Step 3: Test File Import
#
# Replace the UNI in the steps with your UNI.

# %%
import dff9_HW0

# %%
dff9_HW0.t1()
# Out:
# 'dff9 says Hello World'

# %% [markdown]
# The text above should look like my example, but with you UNI.
#
#
# __Note:__ Any time you change the underlying Python file, you must restart the kernel using the menu. You must then re-import and rerun any cells.

# %% [markdown]
# ## Step 4: Install PyMYSQL and iPython-SQL
#
#
# - You run the commands below in an Anaconda terminal window.
#
#
# - [Install](https://anaconda.org/anaconda/pymysql) ```pymysql``` in your Anaconda environment.
#
#
# - [Install](https://anaconda.org/conda-forge/ipython-sql) ```iPython-SQL``` in your Anaconda environment.
#
#
# - Restart the notebook Kernel.
#
#
# - The following cell should execute.

# %%
import pymysql
pymysql.__version__
# Out:
# '1.0.2'

# %% [markdown]
# - In the cell below, replace ```dbuser:dbuserdbuser``` with your MySQL user ID and password.

# %%
# %load_ext sql

# %sql mysql+pymysql://dbuser:dbuserdbuser@localhost
# Out:
# 'Connected: dbuser@None'

# %% [markdown]
# - The following is a simple test. You should get similar results, but your might be slightly different.

# %%
# %sql show tables from information_schema
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 73 rows affected.
# [('ADMINISTRABLE_ROLE_AUTHORIZATIONS',),
#  ('APPLICABLE_ROLES',),
#  ('CHARACTER_SETS',),
#  ('CHECK_CONSTRAINTS',),
#  ('COLLATION_CHARACTER_SET_APPLICABILITY',),
#  ('COLLATIONS',),
#  ('COLUMN_PRIVILEGES',),
#  ('COLUMN_STATISTICS',),
#  ('COLUMNS',),
#  ('ENABLED_ROLES',),
#  ('ENGINES',),
#  ('EVENTS',),
#  ('FILES',),
#  ('INNODB_BUFFER_PAGE',),
#  ('INNODB_BUFFER_PAGE_LRU',),
#  ('INNODB_BUFFER_POOL_STATS',),
#  ('INNODB_CACHED_INDEXES',),
#  ('INNODB_CMP',),
#  ('INNODB_CMP_PER_INDEX',),
#  ('INNODB_CMP_PER_INDEX_RESET',),
#  ('INNODB_CMP_RESET',),
#  ('INNODB_CMPMEM',),
#  ('INNODB_CMPMEM_RESET',),
#  ('INNODB_COLUMNS',),
#  ('INNODB_DATAFILES',),
#  ('INNODB_FIELDS',),
#  ('INNODB_FOREIGN',),
#  ('INNODB_FOREIGN_COLS',),
#  ('INNODB_FT_BEING_DELETED',),
#  ('INNODB_FT_CONFIG',),
#  ('INNODB_FT_DEFAULT_STOPWORD',),
#  ('INNODB_FT_DELETED',),
#  ('INNODB_FT_INDEX_CACHE',),
#  ('INNODB_FT_INDEX_TABLE',),
#  ('INNODB_INDEXES',),
#  ('INNODB_METRICS',),
#  ('INNODB_SESSION_TEMP_TABLESPACES',),
#  ('INNODB_TABLES',),
#  ('INNODB_TABLESPACES',),
#  ('INNODB_TABLESPACES_BRIEF',),
#  ('INNODB_TABLESTATS',),
#  ('INNODB_TEMP_TABLE_INFO',),
#  ('INNODB_TRX',),
#  ('INNODB_VIRTUAL',),
#  ('KEY_COLUMN_USAGE',),
#  ('KEYWORDS',),
#  ('OPTIMIZER_TRACE',),
#  ('PARAMETERS',),
#  ('PARTITIONS',),
#  ('PLUGINS',),
#  ('PROCESSLIST',),
#  ('PROFILING',),
#  ('REFERENTIAL_CONSTRAINTS',),
#  ('RESOURCE_GROUPS',),
#  ('ROLE_COLUMN_GRANTS',),
#  ('ROLE_ROUTINE_GRANTS',),
#  ('ROLE_TABLE_GRANTS',),
#  ('ROUTINES',),
#  ('SCHEMA_PRIVILEGES',),
#  ('SCHEMATA',),
#  ('ST_GEOMETRY_COLUMNS',),
#  ('ST_SPATIAL_REFERENCE_SYSTEMS',),
#  ('ST_UNITS_OF_MEASURE',),
#  ('STATISTICS',),
#  ('TABLE_CONSTRAINTS',),
#  ('TABLE_PRIVILEGES',),
#  ('TABLES',),
#  ('TABLESPACES',),
#  ('TRIGGERS',),
#  ('USER_PRIVILEGES',),
#  ('VIEW_ROUTINE_USAGE',),
#  ('VIEW_TABLE_USAGE',),
#  ('VIEWS',)]

# %% [markdown]
# ### Step 5: Load Sample Data
#
#
# - In the directory where you cloned the project, there is a sub-folder ```db_book.```
#
#
# - Start DataGrip.
#
#
# - In DataGrip, choose ```File->New DataSource->MySQL.```
#     - Accept the default name for the data source.
#     - Set the MySQL user ID and password.
#     - You may see a message stating that you need to install database drives. Install the drivers.
#
#
# - Select the newly created data source. The name will ```Run SQL Script```. Navigate to and choose the file ```DDL_drop.sql```.
#
#
# - Do the same for ```smallRelationsInsertFile.sql```.
#
#
# - You will see an icon/text on the side bar labelled ```db_book.``` It may be greyed-out. Right click on the entry and choose ```New query console.``` You may see a message ```Current schema not introspected``` and ```Introspect schema``` on the far right. Click on ```Introspect schema.```
#
#
# - Enter ```select * from course``` in the query console window. Click on the little green arrow to run the query.
#
#
#
# - Take a screen show of your DataGrip window and save the screen show into the folder of the form ```dff9_src``` using your UNI. Remember the name of the file.
#
#
#
# - Set your file name in the cell below replacing the example and run the cell. You should see your screenshot below. Yours will look a little different from mine. As long as yours shows the query result, you are fine.

# %%
file_name = 'Screen Shot 2022-01-23 at 10.27.12 AM.png'

print("\n")
from IPython.display import Image
Image(filename=file_name)

# %% [markdown]
# ## Step 6: Very %sql
#
# - Execute the cell below. Your answer will be similar to mine but may not match exactly.

# %%
# %sql select * from db_book.course
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 13 rows affected.
# [('BIO-101', 'Intro. to Biology', 'Biology', Decimal('4')),
#  ('BIO-301', 'Genetics', 'Biology', Decimal('4')),
#  ('BIO-399', 'Computational Biology', 'Biology', Decimal('3')),
#  ('CS-101', 'Intro. to Computer Science', 'Comp. Sci.', Decimal('4')),
#  ('CS-190', 'Game Design', 'Comp. Sci.', Decimal('4')),
#  ('CS-315', 'Robotics', 'Comp. Sci.', Decimal('3')),
#  ('CS-319', 'Image Processing', 'Comp. Sci.', Decimal('3')),
#  ('CS-347', 'Database System Concepts', 'Comp. Sci.', Decimal('3')),
#  ('EE-181', 'Intro. to Digital Systems', 'Elec. Eng.', Decimal('3')),
#  ('FIN-201', 'Investment Banking', 'Finance', Decimal('3')),
#  ('HIS-351', 'World History', 'History', Decimal('3')),
#  ('MU-199', 'Music Video Production', 'Music', Decimal('3')),
#  ('PHY-101', 'Physical Principles', 'Physics', Decimal('4'))]

# %% [markdown]
# ## Step 7: Pandas, CSV and SQL
#
#
# - Run the cell below.

# %%
import pandas
pandas.__version__
# Out:
# '0.25.1'

# %% [markdown]
# - Install [SQLAlchemy](https://anaconda.org/anaconda/sqlalchemy) using an Anaconda prompt.
#
#
# - Restart the notebook kernel and rerun all cells. Then run the cell below.

# %%
from sqlalchemy import create_engine

# %% [markdown]
# - Go into DataGrip. Select your local database, e.g. ```@localhost```.
#
#
# - Open a query console and execute ```create database lahmansdb```. Then execute the cell below.
#
#
# __Note:__ Your answer will be different because I have already loaded tables.

# %%
# %sql show tables from lahmansdb;
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 3 rows affected.
# [('appearances',), ('people',), ('teams',)]

# %% [markdown]
# - There is a folder ```data``` in the project you cloned. There is a file in the folder ```People.csv```.
#
#
# - Execute the following code cell. If you are on Windows, you may have to change the path to the file and may have to replace ```/``` with ```\\``` in paths.
#
#
# - You should see a result similar to mine below.

# %%
df = pandas.read_csv('../data/People.csv')
df
# Out:
#         playerID  birthYear  birthMonth  birthDay birthCountry birthState  \
# 0      aardsda01     1981.0        12.0      27.0          USA         CO
# 1      aaronha01     1934.0         2.0       5.0          USA         AL
# 2      aaronto01     1939.0         8.0       5.0          USA         AL
# 3       aasedo01     1954.0         9.0       8.0          USA         CA
# 4       abadan01     1972.0         8.0      25.0          USA         FL
# ...          ...        ...         ...       ...          ...        ...
# 20353   zupofr01     1939.0         8.0      29.0          USA         CA
# 20354  zuvelpa01     1958.0        10.0      31.0          USA         CA
# 20355  zuverge01     1924.0         8.0      20.0          USA         MI
# 20356  zwilldu01     1888.0        11.0       2.0          USA         MO
# 20357   zychto01     1990.0         8.0       7.0          USA         IL
#
#            birthCity  deathYear  deathMonth  deathDay  ...  nameLast  \
# 0             Denver        NaN         NaN       NaN  ...   Aardsma
# 1             Mobile     2021.0         1.0      22.0  ...     Aaron
# 2             Mobile     1984.0         8.0      16.0  ...     Aaron
# 3             Orange        NaN         NaN       NaN  ...      Aase
# 4         Palm Beach        NaN         NaN       NaN  ...      Abad
# ...              ...        ...         ...       ...  ...       ...
# 20353  San Francisco     2005.0         3.0      25.0  ...      Zupo
# 20354      San Mateo        NaN         NaN       NaN  ...   Zuvella
# 20355        Holland     2014.0         9.0       8.0  ...  Zuverink
# 20356      St. Louis     1978.0         3.0      27.0  ...  Zwilling
# 20357          Monee        NaN         NaN       NaN  ...      Zych
#
#              nameGiven weight height bats throws       debut   finalGame  \
# 0          David Allan  215.0   75.0    R      R  2004-04-06  2015-08-23
# 1          Henry Louis  180.0   72.0    R      R  1954-04-13  1976-10-03
# 2           Tommie Lee  190.0   75.0    R      R  1962-04-10  1971-09-26
# 3       Donald William  190.0   75.0    R      R  1977-07-26  1990-10-03
# 4        Fausto Andres  184.0   73.0    L      L  2001-09-10  2006-04-13
# ...                ...    ...    ...  ...    ...         ...         ...
# 20353     Frank Joseph  182.0   71.0    L      R  1957-07-01  1961-05-09
# 20354             Paul  173.0   72.0    R      R  1982-09-04  1991-05-02
# 20355           George  195.0   76.0    R      R  1951-04-21  1959-06-15
# 20356  Edward Harrison  160.0   66.0    L      L  1910-08-14  1916-07-12
# 20357    Anthony Aaron  190.0   75.0    R      R  2015-09-04  2017-08-19
#
#         retroID    bbrefID
# 0      aardd001  aardsda01
# 1      aaroh101  aaronha01
# 2      aarot101  aaronto01
# 3      aased001   aasedo01
# 4      abada001   abadan01
# ...         ...        ...
# 20353  zupof101   zupofr01
# 20354  zuvep001  zuvelpa01
# 20355  zuveg101  zuverge01
# 20356  zwild101  zwilldu01
# 20357  zycht001   zychto01
#
# [20358 rows x 24 columns]

# %% [markdown]
# - We will now save the data to MySQL. Run the cells below. You will have to change ```dbuser:dbuserdbuser``` to your MySQL user ID and password.

# %%
engine = create_engine("mysql+pymysql://dbuser:dbuserdbuser@localhost")

# %%
df.to_sql('people', con=engine, index=False, if_exists='replace', schema='lahmansdb')

# %% [markdown]
# - Test that you wrote the information to the databases.

# %%
# %sql select * from lahmansdb.people where nameLast='Williams' and bats='L'
# Out:
#  * mysql+pymysql://dbuser:***@localhost
# 19 rows affected.
# [('williar01', 1877.0, 8.0, 24.0, 'USA', 'MA', 'Somerville', 1941.0, 5.0, 16.0, 'USA', 'VA', 'Arlington', 'Art', 'Williams', 'Arthur Frank', None, None, 'L', 'R', '1902-05-07', '1902-09-21', 'willa104', 'williar01'),
#  ('willibi01', 1938.0, 6.0, 15.0, 'USA', 'AL', 'Whistler', None, None, None, None, None, None, 'Billy', 'Williams', 'Billy Leo', 175.0, 73.0, 'L', 'R', '1959-08-06', '1976-10-02', 'willb104', 'willibi01'),
#  ('willibi02', 1932.0, 6.0, 13.0, 'USA', 'SC', 'Newberry', 2013.0, 6.0, 11.0, 'USA', 'CA', 'Berkeley', 'Billy', 'Williams', 'William', 195.0, 75.0, 'L', 'R', '1969-08-15', '1969-08-20', 'willb102', 'willibi02'),
#  ('willicy01', 1887.0, 12.0, 21.0, 'USA', 'IN', 'Wadena', 1974.0, 4.0, 23.0, 'USA', 'WI', 'Eagle River', 'Cy', 'Williams', 'Fred', 180.0, 74.0, 'L', 'L', '1912-07-18', '1930-09-22', 'willc103', 'willicy01'),
#  ('willida05', 1958.0, 2.0, 28.0, 'USA', 'NY', 'Brooklyn', None, None, None, None, None, None, 'Dallas', 'Williams', 'Dallas McKinley', 165.0, 71.0, 'L', 'L', '1981-09-19', '1983-10-02', 'willd101', 'willida05'),
#  ('willida07', 1979.0, 3.0, 12.0, 'USA', 'AK', 'Anchorage', None, None, None, None, None, None, 'David', 'Williams', 'David Aaron', 215.0, 75.0, 'L', 'L', '2001-06-06', '2007-09-24', 'willd002', 'willida07'),
#  ('willide01', 1896.0, 12.0, 13.0, 'USA', 'OR', 'Portland', 1929.0, 3.0, 23.0, 'USA', 'CA', 'San Clemente', 'Denny', 'Williams', 'Evon Daniel', 150.0, 68.0, 'L', 'R', '1921-04-15', '1928-07-18', 'willd105', 'willide01'),
#  ('willigu02', 1888.0, 5.0, 7.0, 'USA', 'NE', 'Omaha', 1964.0, 4.0, 16.0, 'USA', 'IL', 'Sterling', 'Gus', 'Williams', 'August Joseph', 185.0, 72.0, 'L', 'L', '1911-04-12', '1915-06-18', 'willg103', 'willigu02'),
#  ('williju02', 1995.0, 8.0, 20.0, 'USA', 'LA', 'Houma', None, None, None, None, None, None, 'Justin', 'Williams', 'Justin Paul', 235.0, 73.0, 'L', 'R', '2018-07-21', '2021-06-02', 'willj006', 'williju02'),
#  ('willike01', 1890.0, 6.0, 28.0, 'USA', 'OR', 'Grants Pass', 1959.0, 1.0, 22.0, 'USA', 'OR', 'Grants Pass', 'Ken', 'Williams', 'Kenneth Roy', 170.0, 72.0, 'L', 'R', '1915-07-14', '1929-08-10', 'willk101', 'willike01'),
#  ('willile03', 1905.0, 12.0, 2.0, 'USA', 'GA', 'Macon', 1984.0, 11.0, 20.0, 'USA', 'GA', 'Atlanta', 'Leon', 'Williams', 'Leon Theo', 154.0, 70.0, 'L', 'L', '1926-05-26', '1926-09-06', 'willl101', 'willile03'),
#  ('willima02', 1953.0, 7.0, 28.0, 'USA', 'NY', 'Elmira', None, None, None, None, None, None, 'Mark', 'Williams', 'Mark Westley', 180.0, 72.0, 'L', 'L', '1977-05-20', '1977-05-22', 'willm105', 'willima02'),
#  ('willima07', 1991.0, 8.0, 21.0, 'USA', 'RI', 'Pawtucket', None, None, None, None, None, None, 'Mason', 'Williams', 'Mason Jordan', 195.0, 73.0, 'L', 'R', '2015-06-12', '2021-06-19', 'willm007', 'willima10'),
#  ('willimi02', 1964.0, 11.0, 17.0, 'USA', 'CA', 'Santa Ana', None, None, None, None, None, None, 'Mitch', 'Williams', 'Mitchell Steven', 180.0, 75.0, 'L', 'L', '1986-04-09', '1997-05-10', 'willm002', 'willimi02'),
#  ('willini01', 1993.0, 9.0, 8.0, 'USA', 'TX', 'Galveston', None, None, None, None, None, None, 'Nick', 'Williams', 'Billy Nicholas', 215.0, 75.0, 'L', 'L', '2017-06-30', '2021-04-13', 'willn001', 'willini01'),
#  ('willira01', 1975.0, 9.0, 18.0, 'USA', 'TX', 'Harlingen', None, None, None, None, None, None, 'Randy', 'Williams', 'Randall Duane', 200.0, 75.0, 'L', 'L', '2004-09-11', '2011-08-05', 'willr003', 'willira01'),
#  ('williri02', 1893.0, 12.0, 18.0, 'USA', 'CA', 'Santa Cruz', 1966.0, 4.0, 24.0, 'USA', 'AZ', 'Cottonwood', 'Rinaldo', 'Williams', 'Rinaldo Louis', None, None, 'L', 'R', '1914-10-08', '1914-10-10', 'willr103', 'williri02'),
#  ('willist01', 1892.0, 1.0, 31.0, 'USA', 'MT', 'Cascade', 1979.0, 6.0, 29.0, 'USA', 'MN', 'Deer River', 'Steamboat', 'Williams', 'Rees Gephardt', 170.0, 71.0, 'L', 'R', '1914-07-12', '1916-10-01', 'wills101', 'willist01'),
#  ('willite01', 1918.0, 8.0, 30.0, 'USA', 'CA', 'San Diego', 2002.0, 7.0, 5.0, 'USA', 'FL', 'Inverness', 'Ted', 'Williams', 'Theodore Samuel', 205.0, 75.0, 'L', 'R', '1939-04-20', '1960-09-28', 'willt103', 'willite01')]

# %% [markdown]
# ## Step 7: Done (Non-Programming)
#
# - You are done.

# %% [markdown]
# ## Programming Track

# %% [markdown]
# - Include a screen capture of your PyCharm execution of the web application. Your should look like the one below but may be different.

# %%
file_name = 'pycharm.png'

print("\n")
from IPython.display import Image
Image(filename=file_name)

# %% [markdown]
# - Put a screen capture of access the web page. Yours will look similar to mine but may be slightly different.

# %%
file_name = 'browser.png'

print("\n")
from IPython.display import Image
Image(filename=file_name)
